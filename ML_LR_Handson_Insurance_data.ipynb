# %%
import numpy as np # for numerical calculation in python
import pandas as pd # for data manipulation
import matplotlib.pyplot as plt # for data visualisation
import seaborn as sns # for data visualisation

# %%
insurance = pd.read_csv('new_insurance_data (1) (3).csv')
insurance.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 insurance = pd.read_csv('new_insurance_data (1) (3).csv')
#       2 insurance.head()
#
# File ~/.python/current/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# ***Performing EDA***

# %%
#checking size and dimension of data
insurance.shape
# Out:
# (1338, 13)

# %%
#checking info about data
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
# ...

# %%
#Checking Null Values
insurance.isna().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
#Checking Description of Data
insurance.describe().round()
# Out:
#           age     bmi  children  Claim_Amount  past_consultations  \
# count  1329.0  1335.0    1333.0        1324.0              1332.0
# mean     39.0    31.0       1.0       33361.0                15.0
# std      14.0     6.0       1.0       15617.0                 7.0
# min      18.0    16.0       0.0        1920.0                 1.0
# 25%      27.0    26.0       0.0       20769.0                 9.0
# 50%      39.0    30.0       1.0       33700.0                15.0
# 75%      51.0    35.0       2.0       45052.0                20.0
# max      64.0    53.0       5.0       77278.0                40.0
#
#        num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# count        1335.0                1334.0                           1336.0
# mean       910005.0            15841792.0                              1.0
# std         91886.0            26693048.0                              1.0
# ...

# %%
#Checking description for object data type
insurance.describe(include='O')
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %%
#Checking Distribution of data
sns.distplot(x=insurance['age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-8-59f5213f46c0>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=insurance['age'])

# %%
sns.distplot(x=insurance['bmi'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-59-43eabac22da6>:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
# numerical_cols = insurance.select_dtypes(include=np.number).columns
# insurance[numerical_cols].skew()

# %%
sns.displot(x=insurance['age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# for i in insurance:
#   sns.boxplot(insurance[i])
#   plt.show()

# %%
import plotly.express as px
fig = px.box(insurance,y='age')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !pip install sweetviz

# %%
# import sweetviz as sv
# report = sv.analyze(insurance)
# report.show_html("sweetviz_report.html")

# %%
# !pip install autoviz

# %%
# from autoviz.AutoViz_Class import AutoViz_Class

# AV = AutoViz_Class()

# report = AV.AutoViz("/content/new_insurance_data (1) (3).csv")

# %%
insurance.isna().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
#filling Null Values one by one
insurance['age'] = insurance['age'].fillna(insurance['age'].median())
insurance['bmi'] = insurance['bmi'].fillna(insurance['bmi'].median())
insurance['children'] = insurance['children'].fillna(insurance['children'].median())
insurance['Claim_Amount'] = insurance['Claim_Amount'].fillna(insurance['Claim_Amount'].median())
insurance['past_consultations'] = insurance['past_consultations'].fillna(insurance['past_consultations'].median())
insurance['num_of_steps'] = insurance['num_of_steps'].fillna(insurance['num_of_steps'].median())
insurance['Hospital_expenditure'] = insurance['Hospital_expenditure'].fillna(insurance['Hospital_expenditure'].median())
insurance['NUmber_of_past_hospitalizations'] = insurance['NUmber_of_past_hospitalizations'].fillna(insurance['NUmber_of_past_hospitalizations'].median())
insurance['Anual_Salary'] = insurance['Anual_Salary'].fillna(insurance['Anual_Salary'].median())

# %%
# filling Null values at once
for i in insurance:
  if insurance[i].dtype != 'object':
    insurance[i]=insurance[i].fillna(insurance[i].median())
  else:
    insurance[i]=insurance[i].fillna(insurance[i].mode()[0])

# %%
insurance.isna().sum()
# Out:
# age                                0
# sex                                0
# bmi                                0
# children                           0
# smoker                             0
# Claim_Amount                       0
# past_consultations                 0
# num_of_steps                       0
# Hospital_expenditure               0
# NUmber_of_past_hospitalizations    0
# Anual_Salary                       0
# region                             0
# charges                            0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.pairplot(insurance,y_vars=['charges'],x_vars=['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
       'past_consultations', 'num_of_steps', 'Hospital_expenditure',
       'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region'])

# %%
#feature engineering
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
insurance['smoker']=le.fit_transform(insurance['smoker'])
insurance['smoker']=insurance['smoker'].astype(int)

# %%
numerical_cols = insurance.select_dtypes(include=np.number).columns
correlation = insurance[numerical_cols].corr()
correlation
# Out:
#                                       age       bmi  children    smoker  \
# age                              1.000000  0.112174  0.041710 -0.028792
# bmi                              0.112174  1.000000  0.007790  0.003659
# children                         0.041710  0.007790  1.000000  0.009608
# smoker                          -0.028792  0.003659  0.009608  1.000000
# Claim_Amount                     0.122873  0.093447  0.041607  0.334410
# past_consultations               0.168479  0.130701  0.054806  0.502794
# num_of_steps                     0.513066  0.135994  0.163478  0.665656
# Hospital_expenditure             0.137208  0.256924  0.025315  0.662698
# NUmber_of_past_hospitalizations  0.359637  0.137115  0.185546  0.588682
# Anual_Salary                     0.163478  0.241550  0.041260  0.739676
# charges                          0.293735  0.198745  0.070877  0.787251
#
#                                  Claim_Amount  past_consultations  \
# ...

# %%
plt.figure(figsize=(8,4))
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
#Extra Dataset for understanding pairplot
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Extra Dataset for understanding pairplot
sns.pairplot(df)

# %%
#Extra Dataset for understanding pairplot
sns.pairplot(df,hue='species')

# %%
plt.figure(figsize=(10,8))
plt.plot(insurance['num_of_steps'],insurance['charges'])
plt.xlabel('num_of_steps') # Added x-axis label for clarity.
plt.ylabel('charges') # Added y-axis label for clarity.
plt.title('Line Plot of num_of_steps vs charges') # Added title for clarity.
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
#Feature selection
x=insurance.drop(columns=['charges','age','sex','bmi','children','region'])
y=insurance['charges']

# %%
#spliting the data in test train
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=5)

# %%
#standardising the data as because my dont have bisaness towards bigger number
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
#creating model
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(x_test)

# %%
prediction
# Out:
# array([ 7.37670601e+03,  3.89425861e+04,  4.04795294e+04,  1.13772927e+03,
#         1.29381991e+04,  7.58316241e+03,  1.01733529e+04,  3.51737368e+03,
#         3.83353239e+04,  1.24287997e+04,  1.10455838e+04,  7.50503192e+03,
#         8.38529404e+03,  1.75395529e+04,  4.34437118e+04,  1.22208896e+04,
#         4.69585291e+04,  1.17201148e+04,  8.01594407e+03,  7.12647163e+03,
#         1.58149142e+04,  4.56036132e+04,  9.50861005e+03,  1.50345068e+03,
#         5.03882920e+03,  2.39743813e+04,  1.98268278e+04,  8.68278444e+03,
#         6.72877717e+03,  3.71815416e+03,  2.62328996e+04,  7.04545831e+03,
#         6.61721593e+02,  4.17405102e+04,  1.60740969e+03,  1.22775337e+04,
#         4.60832142e+04,  1.13821513e+04,  1.79622225e+04,  1.53754617e+04,
#         7.64283001e+03,  1.20062702e+04, -8.16668318e+02,  1.74489207e+04,
#         1.11874429e+04,  8.36301678e+03,  4.38117013e+03,  1.15611299e+04,
# ...

# %%
#for testing purpose we need to use some evlution matrix
from sklearn.metrics import *

# %%
r2_score(y_test,prediction)
# Out:
# 0.9804918193133202

# %%
mean_squared_error(y_test,prediction)
# Out:
# 3611479.085855666
